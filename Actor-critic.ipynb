# %%
#Actor_critic
import tensorflow as tf
import numpy as np
import os
import gym

#環境はcar_envで書く
import pyglet

"""やり直す時には全てのグラフを消す必要あり"""

# %%
#Actor_critic
import tensorflow as tf
import numpy as np
import os
import gym

#環境はcar_envで書く
import pyglet


#class Environment
class CarEnv(object):
    n_sensor=5#センサーの数　距離などを測るためのもの
    action_dim=1
    state_dim=n_sensor
    viewer=None#観測者
    viewer_xy=(500,500)#観測者の位置
    sensor_max=150.0#センサーの感度
    start_point=[450,300]#初期値
    speed=50.0#車の速度
    dt=0.1#時間の刻み幅
    
    def __init__(self,discrete_action=False):
        self.is_discrete_action=discrete_action
        if discrete_action:
            self.actions=[-1,0,1]#行動の種類
        else:
            self.action_bound=[-1,1]
            
        self.terminal=False#終了の判定
        
        #車の座標 (x,y,θ,w,l)
        self.car_info=np.array([0,0,0,20,40],dtype=np.float64)
        
        #障害物の設置
        self.obstacle_points=np.array([[120,120],[380,120],[380,380],[120,380],])
        self.sensor_info=self.sensor_max+np.zeros((self.n_sensor,3)) #(distance,end_x,end_y)
        
        
    def step(self,action):
        """next_state,reward,terminal"""
        if self.is_discrete_action:
            action=self.actions[action]#actionのインデクス
        else:
            action=np.clip(action,*self.action_bound)[0]
        
        #θについて
        self.car_info[2]+=action*np.pi/30
        #x,y
        self.car_info[:2]=self.car_info[:2]+self.speed*self.dt*np.array([np.cos(self.car_info[2]),np.sin(self.car_info[2])])
        
        #センサーのupdate
        self.update_sensor()
        
        #状態と報酬
        s=self.get_state()
        r=-1 if self.terminal else 0
        
        return s,r,self.terminal
    
    def reset(self):
        """初期化"""
        self.terminal=False
        self.car_info[:3]=np.array([*self.start_point,-np.pi/2])
        self.update_sensor()
        
        return self.get_state()
        
        
    def render(self):
        """観測状態を描画するためにviewer classを定義"""
        if self.viewer is None:
            self.viewer=Viewer(*self.viewer_xy,self.car_info,self.sensor_info,self.obstacle_points)
            
        self.viewer.render()
        
    def sample_action(self):
        if self.is_discrete_action:
            a-np.random.choice(list(range(3)))#3つの行動のインデクスから取り出す
        else:
            a=np.random.uniform(*self.action_bound,size=self.action_dim)
            
        return a
            
 
        
    def update_sensor(self):
        cx,cy,rotate=self.car_info[:3]
        
        n_sensors=len(self.sensor_info)
        sensor_theta=np.linspace(-np.pi/2,np.pi/2,n_sensors)#sensorの視角
        xs=cx+(np.zeros((n_sensors,))+self.sensor_max)*np.cos(sensor_theta)
        ys=cy+(np.zeros((n_sensors,))+self.sensor_max)*np.sin(sensor_theta)
        
        #sensorの座標
        xy_s=np.array([[x_s,y_s] for x_s,y_s in zip(xs,ys)])
        
        tmp_x=xy_s[:,0]-cx
        tmp_y=xy_s[:,1]-cy
        
        rotated_x=tmp_x*np.cos(rotate)-tmp_y*np.sin(rotate)
        rotated_y=tmp_x*np.sin(rotate)+tmp_y*np.sin(rotate)
        
        #x,yを変換する
        self.sensor_info[:,-2:]=np.vstack([rotated_x+cx,rotated_y+cy]).T
        
        
        #ゲーム内の車同士の衝突
        q=np.array([cx,cy])
        
        for si in range(len(self.sensor_info)):
            #s
            s=self.sensor_info[si,-2:]-q
            possible_sensor_distance=[self.sensor_max]
            possible_intersections=[self.sensor_info[si,-2:]]#x,y
            
            for op in range(len(self.obstacle_points)):
                p=self.obstacle_points[op]
                r=self.obstacle_points[(op+1)%len(self.obstacle_points)]-self.obstacle_points[op]
                
                #衝突する可能性
                if np.cross(r,s)!=0:
                    #衝突確率を表示
                    t=np.cross((q-p),s)/np.cross(r,s)
                    u=np.cross((q-p),r)/np.cross(r,s)
                    
                    if 0<=t<=1 and 0<=u<=1:
                        intersection=q+u*s
                        possible_intersections.append(intersection)
                        possible_sensor_distance.append(np.linalg.norm(u*s))
                        
            #ゲーム空間から出る場合
            game_xy=np.array([[0,0],[self.viewer_xy[0],0],[*self.viewer_xy],[0,self.viewer_xy[1]],[0,0]])
            
            #四つの端がある
            for ed in range(4):
                p=game_xy[ed]
                r=game_xy[(ed+1)%len(game_xy)]-game_xy[ed]
                
                if np.cross(r,s)!=0:
                    t=np.cross((q-p),s)/np.cross(r,s)
                    u=np.cross((q-p),r)/np.cross(r,s)
                    
                    if 0<=u<=1 and 0<=t<=1:
                        intersection=p+t*r
                        possible_intersections.append(intersection)
                        possible_sensor_distance.append(np.linalg.norm(intersection-q))
                        
                        
            distance=np.min(possible_sensor_distance)
            distance_index=np.argmin(possible_sensor_distance)
            self.sensor_info[si,0]=distance
            self.sensor_info[si,-2:]=possible_intersections[distance_index]
            
            if distance<self.car_info[-1]/2:
                self.terminal=True
                
                        
        
        
        
        
    def get_state(self):
        s=self.sensor_info[:,0].flatten()/self.sensor_max
        return s
    
    
    
    
class Viewer(pyglet.window.Window):
    color = {
        'background': [1]*3 + [1]
    }
    fps_display = pyglet.clock.ClockDisplay()
    bar_thc = 5

    def __init__(self, width, height, car_info, sensor_info, obstacle_coords):
        super(Viewer, self).__init__(width, height, resizable=False, caption='2D car', vsync=False)  # vsync=False to not use the monitor FPS
        self.set_location(x=80, y=10)
        pyglet.gl.glClearColor(*self.color['background'])

        self.car_info = car_info
        self.sensor_info = sensor_info

        self.batch = pyglet.graphics.Batch()
        background = pyglet.graphics.OrderedGroup(0)
        foreground = pyglet.graphics.OrderedGroup(1)

        self.sensors = []
        line_coord = [0, 0] * 2
        c = (73, 73, 73) * 2
        for i in range(len(self.sensor_info)):
            self.sensors.append(self.batch.add(2, pyglet.gl.GL_LINES, foreground, ('v2f', line_coord), ('c3B', c)))

        car_box = [0, 0] * 4
        c = (249, 86, 86) * 4
        self.car = self.batch.add(4, pyglet.gl.GL_QUADS, foreground, ('v2f', car_box), ('c3B', c))

        c = (134, 181, 244) * 4
        self.obstacle = self.batch.add(4, pyglet.gl.GL_QUADS, background, ('v2f', obstacle_coords.flatten()), ('c3B', c))

    def render(self):
        pyglet.clock.tick()
        self._update()
        self.switch_to()
        self.dispatch_events()
        self.dispatch_event('on_draw')
        self.flip()

    def on_draw(self):
        self.clear()
        self.batch.draw()
        # self.fps_display.draw()

    def _update(self):
        cx, cy, r, w, l = self.car_info

        # sensors
        for i, sensor in enumerate(self.sensors):
            sensor.vertices = [cx, cy, *self.sensor_info[i, -2:]]

        # car
        xys = [
            [cx + l / 2, cy + w / 2],
            [cx - l / 2, cy + w / 2],
            [cx - l / 2, cy - w / 2],
            [cx + l / 2, cy - w / 2],
        ]
        r_xys = []
        for x, y in xys:
            tempX = x - cx
            tempY = y - cy
            # apply rotation
            rotatedX = tempX * np.cos(r) - tempY * np.sin(r)
            rotatedY = tempX * np.sin(r) + tempY * np.cos(r)
            # rotated x y
            x = rotatedX + cx
            y = rotatedY + cy
            r_xys += [x, y]
        self.car.vertices = r_xys

# %%
#2Dcar
np.random.seed(1)
tf.set_random_seed(1)
DISCRETE_ACTION=False
env=CarEnv(DISCRETE_ACTION)
#parameters
MAX_EPISODES=1000
MAX_STEPS=600

#2D car
ACTION_DIM=env.action_dim#行動の数
STATE_DIM=env.state_dim#状態の数
ACTION_BOUND=env.action_bound#行動の制限
LOAD=False
RENDER=True#描画するかどうか


TRAIN_INTERVAL_2=300
TRAIN_INTERVAL_1=400
BATCH_SIZE=16
LEARNING_RATE=0.0001
MEMORY_CAPACITY=2000
GAMMA=0.9
VAR_MIN=0.1

# %%
#実行版

#入力データ(s,a,next_s)
with tf.name_scope('S'):
    S=tf.placeholder(tf.float32,shape=[None,STATE_DIM],name='s')
with tf.name_scope('R'):
    R=tf.placeholder(tf.float32,shape=[None,1],name='r')
with tf.name_scope('S_'):
    S_=tf.placeholder(tf.float32,shape=[None,STATE_DIM],name='s_')
    
#memory
class Memory(object):
    """dims:人数"""
    def __init__(self,capacity,dims):
        self.capacity=capacity
        self.memory=np.zeros((capacity,dims))
        self.count=0
        
    def memorize(self,s,a,r,s_):
        #遷移に保存
        transition=np.hstack((s,a,r,s_))#行方向に結合
        index=self.count%self.capacity#新しい記憶に
        self.memory[index,:]=transition
        self.count+=1
        
    def sample(self,batch_size):
        #ランダムにメモリを返す
        indexes=np.random.choice(self.capacity,batch_size)
        
        return self.memory[indexes,:]
    
    
#actor
class Actor(object):
    
    def __init__(self,sess,action_dim,action_bound,learning_rate):
        self.sess=sess#実行インスタンス
        self.action_dim=action_dim
        self.action_bound=action_bound
        self.lr=learning_rate
        self.t=0
        
        #create network advを返す　行動確率に等しい
        with tf.variable_scope('Actor'):
            self.a=self._build_net(S, scope='eval_net', trainable=True)
            self.a_=self._build_net(S_, scope='target_net', trainable=False)
            
        #それぞれのネットワークのパラメタ
        self.main_network_params=tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES,scope='Actor/eval_net')
        self.target_network_params=tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES,scope='Actor/target_net')
            
            
    def _build_net(self, s, scope, trainable):
        with tf.variable_scope(scope):
            #重みとバイアスの初期化
            init_w=tf.contrib.layers.xavier_initializer()
            init_b=tf.constant_initializer(0.001)
            #全結合層 重みを更新する層にはtrainableを設定
            net=tf.layers.dense(s,100,activation=tf.nn.relu,kernel_initializer=init_w,bias_initializer=init_b,trainable=trainable)
            net=tf.layers.dense(net,20,activation=tf.nn.relu,kernel_initializer=init_w,bias_initializer=init_b,trainable=trainable)
            with tf.variable_scope('a'):
                #adv
                actions=tf.layers.dense(net,self.action_dim,activation=tf.nn.tanh,kernel_initializer=init_w,name='a',trainable=trainable)
                a_sc=tf.multiply(actions,self.action_bound,name='a_sc')
                
                
        return a_sc
        
    def learning(self,s):
        #状態の入力
        self.sess.run(self.train_op,feed_dict={S:s})
            
        #parameterの更新
            
        if self.t%TRAIN_INTERVAL_1==0:
            self.sess.run([tf.assign(t,m) for m,t in zip(self.main_network_params,self.target_network_params)])
        self.t+=1
            
    def opt(self,a_grads):
        with tf.variable_scope('policy_grads'):
            self.policy_grads=tf.gradients(ys=self.a,xs=self.main_network_params,grad_ys=a_grads)
                
        with tf.variable_scope('actor_train'):
            optimizer=tf.train.RMSPropOptimizer(-self.lr)
            self.train_op=optimizer.apply_gradients(zip(self.policy_grads,self.main_network_params))
             
            
    def get_action(self,s):
        #stateの配列を一元化
        s=s[np.newaxis,:]
        return self.sess.run(self.a,feed_dict={S:s})[0]
    
    
class Critic(object):
    #評価するためにはs,aが必要
    def __init__(self,sess,a,a_):
        self.sess=sess
        self.num_actions=ACTION_DIM
        self.num_states=STATE_DIM
        self.t=0
        
        with tf.variable_scope('Critic'):
            #main
            self.a=a
            self.q_main=self._build_net(S,self.a,scope='eval_net',trainable=True)
            
            #target
            self.a_=a_
            self.q_target=self._build_net(S_,self.a_,scope='target_net',trainable=False)
            
            #weights_params
            self.main_network_weights=tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES,scope='Critic/eval_net')
            self.target_network_weights=tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES,scope='Critic/target_net')
            
            
        #最適化のインスタンス
        with tf.variable_scope('target_q'):
            self.target_q=self.q_target*GAMMA+R
            
        with tf.variable_scope('loss'):
            self.loss=tf.reduce_mean(tf.square(self.target_q-self.q_main))
            
        with tf.variable_scope('Critic_train'):
            optimizer=tf.train.RMSPropOptimizer(LEARNING_RATE)
            self.train_op=optimizer.minimize(self.loss)
            
        with tf.variable_scope('a_grads'):
            self.a_grads=tf.gradients(self.q_main,self.a)[0]
            
    def _build_net(self,s,a,scope,trainable):
        with tf.variable_scope(scope):
            init_w=tf.contrib.layers.xavier_initializer()
            init_b=tf.constant_initializer(0.01)
            
            #state,actionで別々に総入力関数を出すことがポイント
            with tf.variable_scope('l1'):
                n_l1=100
                w1_s=tf.get_variable('w1_s',[STATE_DIM,n_l1],initializer=init_w,trainable=trainable)
                w1_a=tf.get_variable('w1_a',[ACTION_DIM,n_l1],initializer=init_w,trainable=trainable)
                b1=tf.get_variable('b1',[1,n_l1],initializer=init_b,trainable=trainable)
                net=tf.nn.relu6(tf.matmul(s,w1_s)+tf.matmul(a,w1_a)+b1)
            net=tf.layers.dense(net,20,activation=tf.nn.relu,kernel_initializer=init_w,bias_initializer=init_b,trainable=trainable)
            
            with tf.variable_scope('q'):
                q=tf.layers.dense(net,1,kernel_initializer=init_w,bias_initializer=init_b,trainable=trainable)
                
        return q
    
    def learning(self,s,a,r,s_):
        self.sess.run(self.train_op,feed_dict={S:s,self.a:a,R:r,S_:s_})
        if self.t%TRAIN_INTERVAL_2==0:
            self.sess.run([tf.assign(t,m) for m,t in zip(self.main_network_weights,self.target_network_weights)])
            
        self.t+=1
        
#main
sess=tf.Session()

actor=Actor(sess,ACTION_DIM,ACTION_BOUND[1],LEARNING_RATE)
critic=Critic(sess,actor.a,actor.a_)#actor側の行動確率を引数に
actor.opt(critic.a_grads)

Memo=Memory(MEMORY_CAPACITY,dims=2*STATE_DIM+ACTION_DIM+1)

#保存インスタンス
saver=tf.train.Saver()
#保存先のパス
path='./discrete'if DISCRETE_ACTION else './continuous'

if LOAD:
    #学習済みのデータを用いるときは
    saver.restor(sess,tf.train.latest_chekpoint(path))
else:
    #そうでないときはパラメタを初期化
    sess.run(tf.global_variables_initializer())


def train():
    var=2.0
    for ep in range(MAX_EPISODES):
        s=env.reset()
        step=0

        for t in range(MAX_STEPS):
            if RENDER:
                env.render()

            action=actor.get_action(s)
            action=np.clip(np.random.normal(action,var),*ACTION_BOUND)#random
            #環境にぶち込んでnext_satte,reward,terminalをもらう
            s_,r,terminal=env.step(action)

            Memo.memorize(s,action,r,s_)

            if Memo.count > MEMORY_CAPACITY:
                var=max([var*0.995,VAR_MIN])
                #バッチ生成
                minibatch=Memo.sample(BATCH_SIZE)
                s_batch=minibatch[:,:STATE_DIM]
                a_batch=minibatch[:,STATE_DIM:STATE_DIM+ACTION_DIM]
                r_batch=minibatch[:,-STATE_DIM-1:-STATE_DIM]
                ns_batch=minibatch[:,-STATE_DIM:]

                #actor,criticの双方のネットワークを学習
                critic.learning(s_batch,a_batch,r_batch,ns_batch)
                actor.learning(s_batch)

            #状態の更新
            s=s_
            step+=1

            #終了するかステップ数が最大になった時
            if terminal or t==MAX_STEPS-1:
                print('episode:{}/steps:{}'.format(ep,int(step)))

                break

    #保存
    if not os.path.exists(path):
        os.mkdir(path)
        ckpt_path=os.path.join(path,'DDPG.ckpt')
        save_path=saver.save(sess,ckpt_path)
        print('saved')
        
        
        
        
if __name__=='__main__':
    train()
# Out:
# episode:0/steps:35
# episode:1/steps:42
# episode:2/steps:31
# episode:3/steps:55
# episode:4/steps:34
# episode:5/steps:61
# episode:6/steps:57
# episode:7/steps:63
# episode:8/steps:60
# episode:9/steps:57
# episode:10/steps:24
# episode:11/steps:18
# episode:12/steps:23
# episode:13/steps:22
# episode:14/steps:57
# episode:15/steps:58
# episode:16/steps:33
# episode:17/steps:38
# episode:18/steps:58
# episode:19/steps:23
# episode:20/steps:22
# episode:21/steps:55
# episode:22/steps:58
# episode:23/steps:61
# episode:24/steps:58
# episode:25/steps:69
# episode:26/steps:25
# episode:27/steps:49
# episode:28/steps:58
# episode:29/steps:27
# episode:30/steps:58
# episode:31/steps:36
# episode:32/steps:24
# episode:33/steps:30
# episode:34/steps:60
# episode:35/steps:58
# episode:36/steps:30
# episode:37/steps:59
# episode:38/steps:60
# episode:39/steps:62
# episode:40/steps:34
# episode:41/steps:22
# episode:42/steps:21
# episode:43/steps:64
# episode:44/steps:23
# episode:45/steps:60
# episode:46/steps:57
# episode:47/steps:26
# episode:48/steps:58
# episode:49/steps:27
# episode:50/steps:60
# episode:51/steps:59
# episode:52/steps:58
# episode:53/steps:58
# episode:54/steps:59
# episode:55/steps:58
# episode:56/steps:60
# episode:57/steps:60
# episode:58/steps:59
# episode:59/steps:59
# episode:60/steps:58
# episode:61/steps:60
# episode:62/steps:88
# episode:63/steps:61
# episode:64/steps:65
# episode:65/steps:97
# episode:66/steps:119
# episode:67/steps:101
# episode:68/steps:82
# episode:69/steps:102
# episode:70/steps:278
# episode:71/steps:141
# episode:72/steps:263
# episode:73/steps:80
# episode:74/steps:25
# episode:75/steps:23
# episode:76/steps:21
# episode:77/steps:20
# episode:78/steps:19
# episode:79/steps:20
# episode:80/steps:25
# episode:81/steps:26
# episode:82/steps:27
# episode:83/steps:28
# episode:84/steps:31
# episode:85/steps:36
# episode:86/steps:57
# episode:87/steps:58
# episode:88/steps:37
# episode:89/steps:167
# episode:90/steps:60
# episode:91/steps:57
# episode:92/steps:57
# episode:93/steps:57
# episode:94/steps:57
# episode:95/steps:57
# episode:96/steps:57
# episode:97/steps:57
# episode:98/steps:57
# episode:99/steps:57
# episode:100/steps:57
# episode:101/steps:57
# episode:102/steps:57
# episode:103/steps:55
# episode:104/steps:58
# episode:105/steps:58
# episode:106/steps:56
# episode:107/steps:57
# episode:108/steps:56
# episode:109/steps:54
# episode:110/steps:55
# episode:111/steps:54
# episode:112/steps:56
# episode:113/steps:55
# episode:114/steps:24
# episode:115/steps:48
# episode:116/steps:28
# episode:117/steps:22
# episode:118/steps:23
# episode:119/steps:22
# episode:120/steps:22
# episode:121/steps:21
# episode:122/steps:21
# episode:123/steps:21
# episode:124/steps:22
# episode:125/steps:21
# episode:126/steps:21
# episode:127/steps:22
# episode:128/steps:22
# episode:129/steps:20
# episode:130/steps:22
# episode:131/steps:22
# episode:132/steps:24
# episode:133/steps:23
# episode:134/steps:22
# episode:135/steps:26
# episode:136/steps:23
# episode:137/steps:19
# episode:138/steps:20
# episode:139/steps:18
# episode:140/steps:20
# episode:141/steps:20
# episode:142/steps:18
# episode:143/steps:18
# episode:144/steps:21
# episode:145/steps:21
# episode:146/steps:25
# episode:147/steps:20
# episode:148/steps:22
# episode:149/steps:24
# episode:150/steps:52
# episode:151/steps:22
# episode:152/steps:50
# episode:153/steps:54
# episode:154/steps:49
# episode:155/steps:54
# episode:156/steps:54
# episode:157/steps:54
# episode:158/steps:58
# episode:159/steps:54
# episode:160/steps:54
# episode:161/steps:54
# episode:162/steps:53
# episode:163/steps:57
# episode:164/steps:57
# episode:165/steps:57
# episode:166/steps:57
# episode:167/steps:57
# episode:168/steps:57
# episode:169/steps:57
# episode:170/steps:57
# episode:171/steps:58
# episode:172/steps:58
# episode:173/steps:58
# episode:174/steps:58
# episode:175/steps:58
# episode:176/steps:58
# episode:177/steps:58
# episode:178/steps:58
# episode:179/steps:58
# episode:180/steps:59
# episode:181/steps:59
# episode:182/steps:59
# episode:183/steps:59
# episode:184/steps:59
# episode:185/steps:58
# episode:186/steps:58
# episode:187/steps:58
# episode:188/steps:58
# episode:189/steps:58
# episode:190/steps:58
# episode:191/steps:58
# episode:192/steps:39
# episode:193/steps:41
# episode:194/steps:58
# episode:195/steps:58
# episode:196/steps:58
# episode:197/steps:58
# episode:198/steps:58
# episode:199/steps:59
# episode:200/steps:58
# episode:201/steps:58
# episode:202/steps:59
# episode:203/steps:59
# episode:204/steps:58
# episode:205/steps:59
# episode:206/steps:69
# episode:207/steps:59
# episode:208/steps:60
# episode:209/steps:59
# episode:210/steps:60
# episode:211/steps:60
# episode:212/steps:58
# episode:213/steps:59
# episode:214/steps:58
# episode:215/steps:58
# episode:216/steps:58
# episode:217/steps:58
# episode:218/steps:58
# episode:219/steps:58
# episode:220/steps:58
# episode:221/steps:59
# episode:222/steps:58
# episode:223/steps:58
# episode:224/steps:59
# episode:225/steps:58
# episode:226/steps:60
# episode:227/steps:61
# episode:228/steps:59
# episode:229/steps:60
# episode:230/steps:59
# episode:231/steps:60
# episode:232/steps:58
# episode:233/steps:58
# episode:234/steps:59
# episode:235/steps:58
# episode:236/steps:59
# episode:237/steps:60
# episode:238/steps:62
# episode:239/steps:65
# episode:240/steps:93
# episode:241/steps:62
# episode:242/steps:91
# episode:243/steps:91
# episode:244/steps:82
# episode:245/steps:83
# episode:246/steps:83
# episode:247/steps:83
# episode:248/steps:86
# episode:249/steps:87
# episode:250/steps:90
# episode:251/steps:89
# episode:252/steps:88
# episode:253/steps:77
# episode:254/steps:20
# episode:255/steps:20
# episode:256/steps:20
# episode:257/steps:19
# episode:258/steps:19
# episode:259/steps:20
# episode:260/steps:20
# episode:261/steps:19
# episode:262/steps:19
# episode:263/steps:18
# episode:264/steps:18
# episode:265/steps:19
# episode:266/steps:19
# episode:267/steps:20
# episode:268/steps:21
# episode:269/steps:19
# episode:270/steps:20
# episode:271/steps:20
# episode:272/steps:22
# episode:273/steps:22
# episode:274/steps:21
# episode:275/steps:23
# episode:276/steps:25
# episode:277/steps:25
# episode:278/steps:27
# episode:279/steps:24
# episode:280/steps:32
# episode:281/steps:37
# episode:282/steps:36
# episode:283/steps:41
# episode:284/steps:208
# episode:285/steps:30
# episode:286/steps:30
# episode:287/steps:28
# episode:288/steps:30
# episode:289/steps:26
# episode:290/steps:27
# episode:291/steps:26
# episode:292/steps:29
# episode:293/steps:29
# episode:294/steps:29
# episode:295/steps:26
# episode:296/steps:26
# episode:297/steps:25
# episode:298/steps:25
# episode:299/steps:26
# episode:300/steps:25
# episode:301/steps:24
# episode:302/steps:23
# episode:303/steps:20
# episode:304/steps:20
# episode:305/steps:21
# episode:306/steps:20
# episode:307/steps:20
# episode:308/steps:20
# episode:309/steps:20
# episode:310/steps:20
# episode:311/steps:20
# episode:312/steps:20
# episode:313/steps:19
# episode:314/steps:19
# episode:315/steps:19
# episode:316/steps:19
# episode:317/steps:19
# episode:318/steps:19
# episode:319/steps:20
# episode:320/steps:19
# episode:321/steps:19
# episode:322/steps:19
# episode:323/steps:19
# episode:324/steps:19
# episode:325/steps:18
# episode:326/steps:19
# episode:327/steps:19
# episode:328/steps:19
# episode:329/steps:19
# episode:330/steps:19
# episode:331/steps:19
# episode:332/steps:18
# episode:333/steps:19
# episode:334/steps:19
# episode:335/steps:19
# episode:336/steps:19
# episode:337/steps:19
# episode:338/steps:19
# episode:339/steps:20
# episode:340/steps:20
# episode:341/steps:20
# episode:342/steps:19
# episode:343/steps:19
# episode:344/steps:19
# episode:345/steps:19
# episode:346/steps:19
# episode:347/steps:18
# episode:348/steps:19
# episode:349/steps:20
# episode:350/steps:22
# episode:351/steps:23
# episode:352/steps:22
# episode:353/steps:24
# episode:354/steps:25
# episode:355/steps:29
# episode:356/steps:31
# episode:357/steps:31
# episode:358/steps:18
# episode:359/steps:15
# episode:360/steps:14
# episode:361/steps:16
# episode:362/steps:15
# episode:363/steps:16
# episode:364/steps:15
# episode:365/steps:15
# episode:366/steps:17
# episode:367/steps:19
# episode:368/steps:18
# episode:369/steps:22
# episode:370/steps:57
# episode:371/steps:58
# episode:372/steps:58
# episode:373/steps:64
# episode:374/steps:57
# episode:375/steps:57
# episode:376/steps:58
# episode:377/steps:92
# episode:378/steps:88
# episode:379/steps:88
# episode:380/steps:98
# episode:381/steps:66
# episode:382/steps:95
# episode:383/steps:92
# episode:384/steps:94
# episode:385/steps:88
# episode:386/steps:87
# episode:387/steps:94
# episode:388/steps:88
# episode:389/steps:88
# episode:390/steps:90
# episode:391/steps:88
# episode:392/steps:90
# episode:393/steps:91
# episode:394/steps:93
# episode:395/steps:96
# episode:396/steps:95
# episode:397/steps:95
# episode:398/steps:96
# episode:399/steps:65
# episode:400/steps:94
# episode:401/steps:95
# episode:402/steps:94
# episode:403/steps:92
# episode:404/steps:92
# episode:405/steps:92
# episode:406/steps:91
# episode:407/steps:88
# episode:408/steps:84
# episode:409/steps:83
# episode:410/steps:85
# episode:411/steps:84
# episode:412/steps:30
# episode:413/steps:19
# episode:414/steps:18
# episode:415/steps:19
# episode:416/steps:18
# episode:417/steps:18
# episode:418/steps:18
# episode:419/steps:18
# episode:420/steps:18
# episode:421/steps:18
# episode:422/steps:18
# episode:423/steps:18
# episode:424/steps:17
# episode:425/steps:18
# episode:426/steps:17
# episode:427/steps:18
# episode:428/steps:18
# episode:429/steps:19
# episode:430/steps:20
# episode:431/steps:19
# episode:432/steps:19
# episode:433/steps:19
# episode:434/steps:21
# episode:435/steps:20
# episode:436/steps:21
# episode:437/steps:21
# episode:438/steps:21
# episode:439/steps:23
# episode:440/steps:21
# episode:441/steps:22
# episode:442/steps:21
# episode:443/steps:21
# episode:444/steps:22
# episode:445/steps:22
# episode:446/steps:22
# episode:447/steps:22
# episode:448/steps:23
# episode:449/steps:23
# episode:450/steps:23
# episode:451/steps:24
# episode:452/steps:24
# episode:453/steps:26
# episode:454/steps:27
# episode:455/steps:26
# episode:456/steps:25
# episode:457/steps:27
# episode:458/steps:23
# episode:459/steps:25
# episode:460/steps:26
# episode:461/steps:25
# episode:462/steps:25
# episode:463/steps:24
# episode:464/steps:25
# episode:465/steps:26
# episode:466/steps:28
# episode:467/steps:28
# episode:468/steps:26
# episode:469/steps:26
# episode:470/steps:28
# episode:471/steps:33
# episode:472/steps:29
# episode:473/steps:37
# episode:474/steps:30
# episode:475/steps:31
# episode:476/steps:31
# episode:477/steps:28
# episode:478/steps:31
# episode:479/steps:33
# episode:480/steps:32
# episode:481/steps:36
# episode:482/steps:36
# episode:483/steps:35
# episode:484/steps:94
# episode:485/steps:90
# episode:486/steps:92
# episode:487/steps:89
# episode:488/steps:64
# episode:489/steps:89
# episode:490/steps:90
# episode:491/steps:89
# episode:492/steps:86
# episode:493/steps:84
# episode:494/steps:84
# episode:495/steps:81
# episode:496/steps:83
# episode:497/steps:80
# episode:498/steps:80
# episode:499/steps:80
# episode:500/steps:81
# episode:501/steps:77
# episode:502/steps:77
# episode:503/steps:76
# episode:504/steps:78
# episode:505/steps:76
# episode:506/steps:77
# episode:507/steps:77
# episode:508/steps:81
# episode:509/steps:82
# episode:510/steps:82
# episode:511/steps:81
# episode:512/steps:84
# episode:513/steps:81
# episode:514/steps:83
# episode:515/steps:83
# episode:516/steps:83
# episode:517/steps:80
# episode:518/steps:83
# episode:519/steps:81
# episode:520/steps:82
# episode:521/steps:80
# episode:522/steps:83
# episode:523/steps:83
# episode:524/steps:83
# episode:525/steps:82
# episode:526/steps:84
# episode:527/steps:87
# episode:528/steps:83
# episode:529/steps:83
# episode:530/steps:81
# episode:531/steps:83
# episode:532/steps:81
# episode:533/steps:88
# episode:534/steps:86
# episode:535/steps:84
# episode:536/steps:84
# episode:537/steps:84
# episode:538/steps:83
# episode:539/steps:85
# episode:540/steps:87
# episode:541/steps:87
# episode:542/steps:88
# episode:543/steps:89
# episode:544/steps:86
# episode:545/steps:87
# episode:546/steps:88
# episode:547/steps:90
# episode:548/steps:91
# episode:549/steps:84
# episode:550/steps:87
# episode:551/steps:87
# episode:552/steps:87
# episode:553/steps:86
# episode:554/steps:87
# episode:555/steps:85
# episode:556/steps:109
# episode:557/steps:583
# episode:558/steps:138
# episode:559/steps:293
# episode:560/steps:128
# episode:561/steps:133
# episode:562/steps:138
# episode:563/steps:143
# episode:564/steps:131
# episode:565/steps:121
# episode:566/steps:137
# episode:567/steps:126
# episode:568/steps:121
# episode:569/steps:119
# episode:570/steps:113
# episode:571/steps:108
# episode:572/steps:107
# episode:573/steps:106
# episode:574/steps:104
# episode:575/steps:106
# episode:576/steps:106
# episode:577/steps:110
# episode:578/steps:106
# episode:579/steps:109
# episode:580/steps:108
# episode:581/steps:106
# episode:582/steps:111
# episode:583/steps:107
# episode:584/steps:110
# episode:585/steps:120
# episode:586/steps:120
# episode:587/steps:114
# episode:588/steps:120
# episode:589/steps:120
# episode:590/steps:111
# episode:591/steps:110
# episode:592/steps:119
# episode:593/steps:118
# episode:594/steps:118
# episode:595/steps:120
# episode:596/steps:122
# episode:597/steps:110
# episode:598/steps:123
# episode:599/steps:121
# episode:600/steps:122
# episode:601/steps:112
# episode:602/steps:119
# episode:603/steps:122
# episode:604/steps:120
# episode:605/steps:120
# episode:606/steps:115
# episode:607/steps:113
# episode:608/steps:110
# episode:609/steps:120
# episode:610/steps:111
# episode:611/steps:120
# episode:612/steps:110
# episode:613/steps:113
# episode:614/steps:119
# episode:615/steps:111
# episode:616/steps:118
# episode:617/steps:119
# episode:618/steps:112
# episode:619/steps:115
# episode:620/steps:119
# episode:621/steps:108
# episode:622/steps:107
# episode:623/steps:112
# episode:624/steps:107
# episode:625/steps:107
# episode:626/steps:108
# episode:627/steps:107
# episode:628/steps:104
# episode:629/steps:110
# episode:630/steps:110
# episode:631/steps:119
# episode:632/steps:120
# episode:633/steps:119
# episode:634/steps:121
# episode:635/steps:109
# episode:636/steps:107
# episode:637/steps:120
# episode:638/steps:120
# episode:639/steps:120
# episode:640/steps:111
# episode:641/steps:121
# episode:642/steps:112
# episode:643/steps:109
# episode:644/steps:110
# episode:645/steps:109
# episode:646/steps:110
# episode:647/steps:109
# episode:648/steps:107
# episode:649/steps:109
# episode:650/steps:105
# episode:651/steps:109
# episode:652/steps:109
# episode:653/steps:108
# episode:654/steps:109
# episode:655/steps:108
# episode:656/steps:105
# episode:657/steps:109
# episode:658/steps:107
# episode:659/steps:107
# episode:660/steps:110
# episode:661/steps:109
# episode:662/steps:111
# episode:663/steps:109
# episode:664/steps:108
# episode:665/steps:103
# episode:666/steps:106
# episode:667/steps:103
# episode:668/steps:100
# episode:669/steps:105
# episode:670/steps:104
# episode:671/steps:101
# episode:672/steps:104
# episode:673/steps:101
# episode:674/steps:100
# episode:675/steps:102
# episode:676/steps:102
# episode:677/steps:104
# episode:678/steps:102
# episode:679/steps:101
# episode:680/steps:106
# episode:681/steps:103
# episode:682/steps:99
# episode:683/steps:101
# episode:684/steps:110
# episode:685/steps:105
# episode:686/steps:107
# episode:687/steps:112
# episode:688/steps:103
# episode:689/steps:109
# episode:690/steps:107
# episode:691/steps:106
# episode:692/steps:103
# episode:693/steps:109
# episode:694/steps:113
# episode:695/steps:106
# episode:696/steps:113
# episode:697/steps:108
# episode:698/steps:102
# episode:699/steps:101
# episode:700/steps:102
# episode:701/steps:101
# episode:702/steps:101
# episode:703/steps:102
# episode:704/steps:102
# episode:705/steps:102
# episode:706/steps:102
# episode:707/steps:101
# episode:708/steps:100
# episode:709/steps:99
# episode:710/steps:107
# episode:711/steps:101
# episode:712/steps:99
# episode:713/steps:99
# episode:714/steps:107
# episode:715/steps:111
# episode:716/steps:114
# episode:717/steps:109
# episode:718/steps:121
# episode:719/steps:109
# episode:720/steps:109
# episode:721/steps:112
# episode:722/steps:98
# episode:723/steps:102
# episode:724/steps:100
# episode:725/steps:97
# episode:726/steps:100
# episode:727/steps:103
# episode:728/steps:108
# episode:729/steps:105
# episode:730/steps:107
# episode:731/steps:99
# episode:732/steps:100
# episode:733/steps:101
# episode:734/steps:104
# episode:735/steps:110
# episode:736/steps:103
# episode:737/steps:108
# episode:738/steps:107
# episode:739/steps:108
# episode:740/steps:108
# episode:741/steps:103
# episode:742/steps:109
# episode:743/steps:109
# episode:744/steps:111
# episode:745/steps:111
# episode:746/steps:112
# episode:747/steps:110
# episode:748/steps:144
# episode:749/steps:142
# episode:750/steps:119
# episode:751/steps:145
# episode:752/steps:146
# episode:753/steps:144
# episode:754/steps:149
# episode:755/steps:148
# episode:756/steps:151
# episode:757/steps:120
# episode:758/steps:110
# episode:759/steps:111
# episode:760/steps:109
# episode:761/steps:99
# episode:762/steps:97
# episode:763/steps:93
# episode:764/steps:94
# episode:765/steps:98
# episode:766/steps:94
# episode:767/steps:93
# episode:768/steps:87
# episode:769/steps:38
# episode:770/steps:39
# episode:771/steps:32
# episode:772/steps:30
# episode:773/steps:33
# episode:774/steps:33
# episode:775/steps:32
# episode:776/steps:31
# episode:777/steps:86
# episode:778/steps:91
# episode:779/steps:87
# episode:780/steps:89
# episode:781/steps:89
# episode:782/steps:87
# episode:783/steps:90
# episode:784/steps:85
# episode:785/steps:88
# episode:786/steps:89
# episode:787/steps:88
# episode:788/steps:92
# episode:789/steps:92
# episode:790/steps:89
# episode:791/steps:91
# episode:792/steps:92
# episode:793/steps:90
# episode:794/steps:91
# episode:795/steps:90
# episode:796/steps:89
# episode:797/steps:90
# episode:798/steps:90
# episode:799/steps:88
# episode:800/steps:38
# episode:801/steps:88
# episode:802/steps:87
# episode:803/steps:89
# episode:804/steps:86
# episode:805/steps:88
# episode:806/steps:87
# episode:807/steps:89
# episode:808/steps:87
# episode:809/steps:84
# episode:810/steps:39
# episode:811/steps:87
# episode:812/steps:85
# episode:813/steps:84
# episode:814/steps:86
# episode:815/steps:85
# episode:816/steps:87
# episode:817/steps:87
# episode:818/steps:84
# episode:819/steps:84
# episode:820/steps:83
# episode:821/steps:83
# episode:822/steps:40
# episode:823/steps:81
# episode:824/steps:85
# episode:825/steps:86
# episode:826/steps:88
# episode:827/steps:87
# episode:828/steps:88
# episode:829/steps:87
# episode:830/steps:89
# episode:831/steps:86
# episode:832/steps:86
# episode:833/steps:89
# episode:834/steps:89
# episode:835/steps:90
# episode:836/steps:94
# episode:837/steps:95
# episode:838/steps:115
# episode:839/steps:108
# episode:840/steps:105
# episode:841/steps:82
# episode:842/steps:100
# episode:843/steps:93
# episode:844/steps:105
# episode:845/steps:99
# episode:846/steps:92
# episode:847/steps:98
# episode:848/steps:100
# episode:849/steps:91
# episode:850/steps:111
# episode:851/steps:93
# episode:852/steps:87
# episode:853/steps:83
# episode:854/steps:85
# episode:855/steps:110
# episode:856/steps:103
# episode:857/steps:107
# episode:858/steps:113
# episode:859/steps:136
# episode:860/steps:96
# episode:861/steps:117
# episode:862/steps:121
# episode:863/steps:124
# episode:864/steps:95
# episode:865/steps:122
# episode:866/steps:96
# episode:867/steps:96
# episode:868/steps:104
# episode:869/steps:89
# episode:870/steps:89
# episode:871/steps:103
# episode:872/steps:96
# episode:873/steps:600
# episode:874/steps:600
# episode:875/steps:248
# episode:876/steps:114
# episode:877/steps:97
# episode:878/steps:103
# episode:879/steps:106
# episode:880/steps:123
# episode:881/steps:122
# episode:882/steps:121
# episode:883/steps:122
# episode:884/steps:122
# episode:885/steps:121
# episode:886/steps:123
# episode:887/steps:129
# episode:888/steps:124
# episode:889/steps:385
# episode:890/steps:84
# episode:891/steps:84
# episode:892/steps:82
# episode:893/steps:86
# episode:894/steps:86
# episode:895/steps:83
# episode:896/steps:95
# episode:897/steps:97
# episode:898/steps:90
# episode:899/steps:112
# episode:900/steps:240
# episode:901/steps:101
# episode:902/steps:442
# episode:903/steps:121
# episode:904/steps:119
# episode:905/steps:119
# episode:906/steps:118
# episode:907/steps:121
# episode:908/steps:120
# episode:909/steps:121
# episode:910/steps:135
# episode:911/steps:84
# episode:912/steps:80
# episode:913/steps:77
# episode:914/steps:78
# episode:915/steps:75
# episode:916/steps:80
# episode:917/steps:77
# episode:918/steps:76
# episode:919/steps:78
# episode:920/steps:77
# episode:921/steps:75
# episode:922/steps:76
# episode:923/steps:84
# episode:924/steps:105
# episode:925/steps:103
# episode:926/steps:111
# episode:927/steps:119
# episode:928/steps:97
# episode:929/steps:61
# episode:930/steps:61
# episode:931/steps:131
# episode:932/steps:59
# episode:933/steps:58
# episode:934/steps:59
# episode:935/steps:60
# episode:936/steps:59
# episode:937/steps:104
# episode:938/steps:61
# episode:939/steps:114
# episode:940/steps:64
# episode:941/steps:60
# episode:942/steps:109
# episode:943/steps:61
# episode:944/steps:146
# episode:945/steps:132
# episode:946/steps:60
# episode:947/steps:64
# episode:948/steps:111
# episode:949/steps:118
# episode:950/steps:63
# episode:951/steps:59
# episode:952/steps:122
# episode:953/steps:113
# episode:954/steps:64
# episode:955/steps:122
# episode:956/steps:121
# episode:957/steps:113
# episode:958/steps:106
# episode:959/steps:119
# episode:960/steps:137
# episode:961/steps:101
# episode:962/steps:110
# episode:963/steps:61
# episode:964/steps:105
# episode:965/steps:59
# episode:966/steps:102
# episode:967/steps:98
# episode:968/steps:102
# episode:969/steps:81
# episode:970/steps:82
# episode:971/steps:60
# episode:972/steps:59
# episode:973/steps:85
# episode:974/steps:85
# episode:975/steps:63
# episode:976/steps:99
# episode:977/steps:59
# episode:978/steps:59
# episode:979/steps:59
# episode:980/steps:58
# episode:981/steps:59
# episode:982/steps:59
# episode:983/steps:59
# episode:984/steps:59
# episode:985/steps:60
# episode:986/steps:59
# episode:987/steps:59
# episode:988/steps:59
# episode:989/steps:59
# episode:990/steps:60
# episode:991/steps:59
# episode:992/steps:59
# episode:993/steps:59
# episode:994/steps:60
# episode:995/steps:59
# episode:996/steps:58
# episode:997/steps:57
# episode:998/steps:60
# episode:999/steps:60

# %%
#memory
class Memory(object):
    """dims:人数"""
    def __init__(self,capacity,dims):
        self.capacity=capacity
        self.memory=np.zeros((capacity,dims))
        self.count=0
        
    def memorize(self,s,a,r,s_):
        #遷移に保存
        transition=np.hstack((s,a,r,s_))#行方向に結合
        index=self.count%self.capacity#新しい記憶に
        self.memory[index,:]=transition
        self.count+=1
        
    def sample(self,batch_size):
        #ランダムにメモリを返す
        indexes=np.random.choice(self,capacity,batch_size)
        
        return self.memory[indexes,:]

# %%
#actor
class Actor(object):
    
    def __init__(self,sess,action_dim,action_bound,learning_rate,train_interval):
        self.sess=sess#実行インスタンス
        self.action_dim=action_dim
        self.action_bound=ACTION_BOUND
        self.lr=learning_rate
        self.train_interval=train_interval
        self.t=0
        
        #create network advを返す　行動確率に等しい
        with tf.variable_scope('Actor'):
            self.a=self._build_net(S, scope='eval_net', trainable=True)
            self.a_=self._build_net(S_, scope='target_net', trainable=False)
            
        #それぞれのネットワークのパラメタ
        self.main_network_params=tf.get_collection(tf.GraphKeys.GLOABAL_VARIABLES,scope='Actor/eval_net')
        self.target_network_params=tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES,scope='Actor/target_net')
            
            
    def _build_net(self, s, scope, trainable):
        #これでパラメータの共有化が可能
        with tf.variable_scope(scope):
            #重みとバイアスの初期化
            init_w=tf.contrib.layers.xavier_initializer()
            init_b=tf.constant_initializer(0)
            #全結合層 重みを更新する層にはtrainableを設定
            net=tf.layers.dense(s,100,activation='relu',kernel_initializer=init_w,bias_initializer=init_b,trainable=trainable)
            net=tf.layers.dense(net,20,activation='relu',kernel_initializer=init_w,bias_initializer=init_b,trainable=trainable)
            with tf.variable_scope('a'):
                #adv
                actions=tf.layers.dense(net,self.action_dim,activation=tf.nn.tanh,kernel_initializer=init_w,name='a',trainable=trainable)
                a_sc=tf.multiply(actions,self.action_bound,name='a_sc')
                
                
        return a_sc
        
    def learning(self,s):
        #状態の入力
        self.sess.run(self.train_op,feed_dict={S:s})
            
        #parameterの更新
            
        if self.t%self.train_interval==0:
            self.sess.run([tf.assign(m,t) for m,t in zip(self.main_network_params,self.target_network_params)])
        self.t+=1
            
    def opt(self,a_grads):
        with tf.variable_scope('policy_grads'):
            self.policy_grads=tf.gradients(ys=self.a,xs=self.main_network_params,grad_ys=a_grads)
                
        with tf.variable_scope('actor_train'):
            optimizer=tf.train.RMSPropOptimizer(-self.lr)
            self.train_op=optimizer.apply_gradients(zip(self.policy_grads,self.main_network_params))
             
            
    def get_action(self,s):
        #stateの配列を一元化
        s=s[np.newaxis,:]
        return self.sess.run(self.a,feed_dict={S:s})[0]

# %%
class Critic(object):
    #評価するためにはs,aが必要
    def __init__(self,sess,a,a_):
        self.sess=sess
        self.num_actions=ACTION_DIM
        self.num_states=STATE_DIM
        self.t=0
        
        with tf.variable_scope('Critic'):
            #main
            self.a=a
            self.q_main=self.net(S,self.a,scope='eval_net',trainable=True)
            
            #target
            self.a_=a_
            self.q_target=self.net(S_,self.a_,scope='target_net',trainable=False)
            
            #weights_params
            self.main_network_weights=tf.get_collection(tf.GraphKeys.GLOABAL_VARIABLES,scope='Critic/eval_net')
            self.target_network_weights=tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES,scope='Critic/target_net')
            
            
        #最適化のインスタンス
        with tf.variable_scope('target_q'):
            self.target_q=self.q_target*GAMMA+R
            
        with tf.variable_scope('loss'):
            self.loss=tf.reduce_mean(tf.square(self.target_q-self.q_main))
            
        with tf.variable_scope('Critic_train'):
            optimizer=tf.train.RMSPropOptimizer(LEARNING_RATE)
            self.train_op=optimizer.minimize(self.loss)
            
        with tf.variable_scope('a_grads'):
            self.a_grads=tf.gradients(self.q_main,self.a)[0]
            
    def net(self,s,scope,trainable):
        with tf,variable_scope(scope):
            init_w=tf.contrib.layers.xavier_initializer()
            init_b=tf.constant_initializer(0)
            
            net=tf.layers.dense(s,100,activation='relu',kernel_initializer=init_w,bias_initializer=init_b,trainable=trainable)
            net=tf.layers.dense(net,20,activation='relu',kernel_initializer=init_w,bias_initializer=init_b,trainable=trainable)
            
            with tf.variable_scope('q'):
                q=tf.layers.dense(net,1,kernel_initializer=init_w,bias_initializer=init_b,trainable=trainable)
                
        return q
    
    def learning(self,s,a,r,s_):
        self.sess.run(self.train_op,feed_dict={S:s,self.a:a,R:r,S_:s_})
        if self.t%TRAIN_INTERVAL==0:
            self.sess.run([tf.assign(m,t) for m,t in zip(self.main_network_weights,self.target_network_weights)])
            
        self.t+=1

# %%
#main
sess=tf.Session()

actor=Actor(sess,ACTION_DIM,ACTION_BOUND,LEARNING_RATE,TRAIN_INTERVAL)
critic=Critic(sess,actor.a,actor.a_)#actor側の行動確率を引数に
actor.opt(critic.a_grads)

Memo=Memory(MEMORY_CAPACITY,dims=2*STATE_DIM+ACTION_DIM+1)

#保存インスタンス
saver=tf.train.Saver()
#保存先のパス
path='./discrete'if DISCRETE_ACTION else './continuous'

if LOAD:
    #学習済みのデータを用いるときは
    saver.restor(sess,tf.train.latest_chekpoint(path))
else:
    #そうでないときはパラメタを初期化
    sess.run(tf.global_variables_initializer())


def train():
    var=2.0
    for ep in range(MAX_EPISODES):
        s=env.reset()
        step=0

        for t in range(MAX_STEPS):
            if RENDER:
                env.render()

            action=actor.get_action(s)
            action=np.clip(np.random.normal(a,var),*ACTION_BOUND)#random
            #環境にぶち込んでnext_satte,reward,terminalをもらう
            s_,r,terminal=env.step(a)

            Memo.memorize(s,a,r,s_)

            s_batch=[]
            a_batch=[]
            r_batch=[]
            ns_batch=[]


            if Memo.count > MEMORY_CAPACITY:
                #バッチ生成
                minibatch=Memo.sample(BATCH_SIZE)

                for bt in minibatch:
                    s_batch.append(bt[0])
                    a_batch.append(bt[1])
                    r_batch.append(bt[2])
                    ns_batch.append(bt[3])

                #actor,criticの双方のネットワークを学習
                critic.learning(s_batch,a_batch,r_batch,ns_batch)
                actor.learning(s_batch)

            #状態の更新
            s=s_
            step+=1

            #終了するかステップ数が最大になった時
            if terminal or t==MAX_STEPS-1:
                print('episode:{}/steps:{}'.format(ep,int(step)))

                break

    #保存
    if not os.path.exists(path):
        os.mkdir(path)
        ckpt_path=os.path.join(path,'DDPG.ckpt')
        save_path=saver.save(sess,ckpt_path)
        print('saved')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-a5bdbe033057> in <module>()
#       2 sess=tf.Session()
#       3
# ----> 4 actor=Actor(sess,ACTION_DIM,ACTION_BOUND,LEARNING_RATE,TRAIN_INTERVAL)
#       5 critic=Critic(sess,actor.a,actor.a_)#actor側の行動確率を引数に
#       6 actor.opt(critic.a_grads)
#
# <ipython-input-12-3c173787e796> in __init__(self, sess, action_dim, action_bound, learning_rate, train_interval)
#      12         #create network advを返す　行動確率に等しい
#      13         with tf.variable_scope('Actor'):
# ---> 14             self.a=self._build_net(S, scope='eval_net', trainable=True)
#      15             self.a_=self._build_net(S_, scope='target_net', trainable=False)
#      16
#
# <ipython-input-12-3c173787e796> in _build_net(self, s, scope, trainable)
#      22     def _build_net(self, s, scope, trainable):
#      23         #これでパラメータの共有化が可能
# ---> 24         with tf,variable_scope(scope):
#      25             #重みとバイアスの初期化
#      26             init_w=tf.contrib.layers.xavier_initializer()
#
# AttributeError: __enter__
